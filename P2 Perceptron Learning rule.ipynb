# %%
class Perceptron(object):

    def __init__(self, bias, weights):
        self.bias = bias
        self.weights = weights
        
        
    def __str__(self):
        # print 
        return 'Perceptron(Bias=' + str(self.bias) + ', Weights=' + str(self.weights) + ', inputs=' + str(self.inputs)
    
    
    def activate(self, inputs):
        # Houdt bij wat de som is om over de threshhold te komen.
        total = 0
        self.inputs = inputs
        #ittereert over de inputs en de weights en verminigvuldigd ze.
        for i in range(len(self.inputs)):
            total += self.inputs[i] * self.weights[i]
        
        # bij het totaal wordt de bias opgeteld en checkt vervolgens of hij wel/niet aan moet gaan. 
        total = total + self.bias
        
        if total >= 0:
            act = 1
        else:
            act = 0
            
        return act
    
    
    def update(self, target, x):
        self.x = x
        bias = self.bias
        weights = self.weights
        
        n = 0.1
        error = d – y
        
        #output = perceptron.activate()?
        
        #delta_weights = n * e * x
        #delta_Bias = n * e
        #w_new = w + delta_weights
        #b_new = b + delta_bias
        
        return n * (target[i] - output[i]) * x
        
        

        
        
        
        print(x)

# %% [markdown]
# gegeven target d,
# input x , weights
# w en
# bias b:
#
# output y = f(w ∙ x) met activatiefunctie f en y ∈ {0, 1}
# error e = d – y
# Δw = η ∙ e ∙ x met η een constante learning rate (kies hier η = 0.1)
# Δb = η ∙ e
# w' = w + Δw
# b' = b + Δb
# Ga zelf na dat bovenstaande overeenkomt met deze formule (Koppelingen naar een externe site.):

# %%
InvertGate = Perceptron(0.5 , [-0.51, -1])

# %%
InvertGate.update(0,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2e35e27e508d> in <module>
# ----> 1 InvertGate.update(0,1)
#
# <ipython-input-1-213d2bd5c8ac> in update(self, target, x)
#      41         #b_new = b + delta_bias
#      42
# ---> 43         return n * (target - outputs) * x
#      44
#      45
#
# NameError: name 'outputs' is not defined
